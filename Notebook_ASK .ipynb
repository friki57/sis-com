# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
señal_muestreada=[]
número_muestras=200
señal_digital=[0,1,1,0,0,0,1,1,0,1,1,1,0,1,0]

# %%
for i in range(1,15): 
    u=np.ones(200)  
    m=u*señal_digital[i]
    señal_muestreada=np.concatenate((señal_muestreada,m))

# %%
t=np.linspace(0,5,len(señal_muestreada))
frec_p=5
señal_portadora=np.cos(2*np.pi*frec_p*t)

# %%
señal_mod=señal_portadora*señal_muestreada

# %%
plt.subplot(4,1,1)
plt.plot(señal_muestreada)

# %%
plt.subplot(1,1,1)
plt.plot(señal_portadora)

# %%
plt.subplot(1,1,1)
plt.plot(señal_mod)

# %% [markdown]
# No se observa ningún cambio al reducir el numero de muestras

# %%
número_muestras=3
señal_muestreada=[]

# %%
for i in range(1,15):    
    u=np.ones(número_muestras)  
    m=u*señal_digital[i]   
    señal_muestreada=np.concatenate((señal_muestreada,m))

# %%
t=np.linspace(0,5,len(señal_muestreada))
f2=5

# %%
señal_portadora=np.cos(2*f2*np.pi*t)
señal_mod=señal_portadora*señal_muestreada

# %%
plt.subplot(4,1,1)
plt.plot(señal_muestreada)

# %%
plt.subplot(1,1,1)
plt.plot(señal_portadora)

# %%
plt.subplot(1,1,1)
plt.plot(señal_mod)

# %% [markdown]
# ##¿Cuál es el ancho de banda necesario para la modulación ASK?
#     El  ancho de banda necesario para esta transmisión es mayor que el requerido para modulación de amplitud, es decir, el ancho de banda práctico es el doble del requerido en transmisión banda base.
#
# ##¿en qué consiste la modulación ASK?
#     Modulación por Desplazamiento de Amplitud.
#     Es una modulación de amplitud donde la señal moduladora (datos) es digital. Los dos valores binarios (0 y 1) se representan con dos amplitudes diferentes y es usual que una de las dos amplitudes sea cero; es decir uno de los dígitos binarios se representa mediante la presencia de la portadora a amplitud constante, y el otro dígito se representa mediante la ausencia de la señal portadora, en este caso la frecuencia y la fase se mantiene constante.
#
# ##¿Qué operación matemática representa a la modulación ASK? ¿Esta operación es conmutativa?
#     vASK(t)=A/2(1+vm*(t))sin(wc*t)
#
# ##¿Qué sucede si el número de muestras que tomas es igual a 3? Captura y copia la gráfica resultante y describe lo que pasó
#     si el numero de muestras es mayor tiene mas datos y la señal es mas fluida, pero si es menor son bruscos los cambios en la amplitud de la señal. Como se puede ver en el grafico.

# %%
1.- ¿Cuál es el ancho de banda necesario para la modulación ASK?
el ancho de banda necesario es el doble del requerido en transmisión banda base.

2.- ¿En qué consiste la modulación ASK? 
Es la Modulación por Desplazamiento de Amplitud. Consiste en el una modulación donde la señal moduladora lleva un mensaje binario, por tanto, la señal portadora tiene una amplitud y frecuencia constante. Esto da como resultado que la señal modulada termina teniendo la amplitud de la señal original y la frecuencia de la portadora.

¿Qué operación matemática representa a la modulación ASK? ¿Esta operación es conmutativa?
Es la multiplicación entre la señal portadora y la señal original. Si es conmutativa.

¿Qué sucede si el número de muestras que tomas es igual a 3? 
La señal tiene cambios mucho más bu
